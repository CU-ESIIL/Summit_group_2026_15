# %% [markdown]
# # Linking Remote Sensed Metrics to Field-collected Data: The Focal Data Site Streamer
#
# Group Members: Nyika, Olivia, Lauren, Emily <br>
# Last updated: May 14, 2026 <br>
# Created: May 14, 2026 ESIIL Innovation Summit

# %% [markdown]
# ~text about the purpose of this notebook

# %% [markdown]
# Organization of this notebook:
# 1. Import packages and libraries
# 2. Put in your parameters and site specific information
# 3. Run the code to stream your selected data
# 4. Save your data cube
# 5. Save specific save for points or polygons

# %% [markdown]
# # 1. Import Packages and libraries

# %%
## Import libraries
from datetime import datetime
import numpy as np
import pandas as pd
import glob
import re
import os
from pathlib import Path
import rasterio
import xarray
import folium
# import pillow << this was in the LLM requirements file but didnt work here?
import pyproj
import shapely
import fiona
import branca

#from scipy import stats << might want to add scipy to requirements file + venv
#import statsmodels.api as sm
import matplotlib as mpl
import warnings
#import seaborn as sns << might want to add scipy to requirements file + venv
import matplotlib.pyplot as plt
#import cartopy.crs as crs << might want to add scipy to requirements file + venv
#import cartopy.feature as cfeature
from matplotlib.ticker import FormatStrFormatter
from matplotlib import pyplot as plt, ticker as mticker
#from cartopy.io.shapereader import Reader as shpreader
#from cartopy.feature import ShapelyFeature

## Import custom module
# import preprocessing << replace with ours!! and then add to requirements file + venv

# Suppress warnings
warnings.simplefilter('ignore')
# %matplotlib inline
